# %% [markdown]
# <a href="https://colab.research.google.com/github/rarulz/experiments/blob/main/Workshop3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# Seaborn

# %%
#Relplot - note: starting with line 4, comment out all the other lines except the one you want to look at (for example, comment out line 5 and the others if you want to look at the plot on line six, as then you will not need to keep scrolling down to find the plot you wish to see)
import seaborn as sns
tips = sns.load_dataset('tips') #one of the default datasets in seaborn
#tips.head() #quick look of dataframe
#sns.relplot(data = tips, x = 'total_bill', y = 'tip') #simple scatterplot
#sns.relplot(data = tips, x = 'total_bill', y = 'tip', hue = 'day') #scatterplot colored according to day
#sns.relplot(data = tips, x = 'total_bill', y = 'tip', kind = 'line') #Line graph (not very useful for this dataset, as the values do not neatly fit a polynomial-like pattern)
#sns.relplot(data = tips, x = 'total_bill', y = 'tip', col = 'day') #creates multiple graphs, with each column being a different day

# %%
#Lmplot - note: starting with line 4, comment out all the other lines except the one you want to look at (for example, comment out line 5 and the others if you want to look at the plot on line six, as then you will not need to keep scrolling down to find the plot you wish to see)
import seaborn as sns
tips = sns.load_dataset('tips') #one of the default datasets in seaborn
#tips.head() #quick look of dataframe
#sns.lmplot(data = tips, x = 'total_bill', y = 'tip') #simple scatterplot with line of best fit (linear regression)
#sns.lmplot(data = tips, x = 'total_bill', y = 'tip', hue = 'day') #scatterplot colored according to day, and creates different best fit line for each day
#sns.lmplot(data = tips, x = 'total_bill', y = 'tip', hue = 'day', markers = ['o','v','p','s']) #creates markers according to the day as well, easier to visualize if people are unable to distinguish color well or it is presented in black and white, can be found by looking at this link: https://matplotlib.org/stable/api/markers_api.html
#sns.lmplot(data = tips, x = 'total_bill', y = 'tip', col = 'day') #creates multiple graphs, with each column being a different day

# %%
#Catplot - note: starting with line 4, comment out all the other lines except the one you want to look at (for example, comment out line 5 and the others if you want to look at the plot on line six, as then you will not need to keep scrolling down to find the plot you wish to see)
import seaborn as sns
exercise = sns.load_dataset('exercise') #one of the default datasets in seaborn
#exercise.head() #quick look of dataframe
#sns.catplot(data = exercise, x = 'time', y = 'pulse', kind = 'swarm') #simple swarmplot that shows the data in each category
#sns.catplot(data = exercise, x = 'time', y = 'pulse', kind = 'box') #boxplot showing the distribution of the pulse after each number of minutes of exercise
#sns.catplot(data = exercise, x = 'time', y = 'pulse', kind = 'violin') #violinplot, also showing the distributin of the pulse after each number of minutes (shows areas where it is greater than more clearly)
sns.catplot(data = exercise, x = 'time', y = 'pulse', col = 'kind', kind = 'bar') #creates multiple graphs, with each column being a different day

# %% [markdown]
# Scikit-learn

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset that comes with the scikit dataset package.
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# Use only one feature
diabetes_X = diabetes_X[:, np.newaxis, 2]

# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets. We use the regr.fit function 
regr.fit(diabetes_X_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# The mean squared error shows how close the regression line is to a set of points, essentially showing the overall error value of the regression line.
print('Mean squared error: %.2f'
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(diabetes_y_test, diabetes_y_pred))

# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test,  color='black')
plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)
# Out:
# Mean squared error: 2548.07
# Coefficient of determination: 0.47
